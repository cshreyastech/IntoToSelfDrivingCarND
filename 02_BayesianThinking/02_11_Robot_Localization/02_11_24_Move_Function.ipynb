# %%
# Program a function that returns a new distribution 
# q, shifted to the right by U units. If U=0, q should 
# be the same as p.

# p=[0, 1, 0, 0, 0]
p=[0, 1, 2, 3, 4]
# U = -1
def move(p, U):
    ## YOUR CODE HERE ##
    
    U = U % len(p)
    q = p[-U:] + p[:-U]
    return q

# move(p, U)
# Out:
# [1, 2, 3, 4, 0]
